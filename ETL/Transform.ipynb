# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
import json

# %%
#Reading in vaccines2018 to Dataframe
vaccines = pd.read_csv("ExtractCSV/vaccines/vaccines2018.csv")
vaccines
# Out:
#           Week Total Doses Distributed
# 0   03/01/2019               ≈ 169.1 M
# 1   02/22/2019               ≈ 169.1 M
# 2   02/15/2019               ≈ 169.1 M
# 3   02/08/2019               ≈ 169.1 M
# 4   02/01/2019               ≈ 168.9 M
# 5   01/25/2019               ≈ 168.6 M
# 6   01/18/2019               ≈ 168.4 M
# 7   01/11/2019               ≈ 168.0 M
# 8   01/04/2019               ≈ 167.0 M
# 9   12/14/2018               ≈ 166.6 M
# 10  12/07/2018               ≈ 165.5 M
# 11  11/30/2018               ≈ 163.8 M
# 12  11/23/2018               ≈ 162.1 M
# 13  11/09/2018               ≈ 159.1 M

# %%
#Transforming DF to usable data
#Number of doses given
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace(" M","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace("≈ ","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace("≈","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].astype(float)
#Number changing from string to date
vaccines["Week"] = pd.to_datetime(vaccines["Week"])
vaccines
# Out:
#          Week  Total Doses Distributed
# 0  2019-03-01                    169.1
# 1  2019-02-22                    169.1
# 2  2019-02-15                    169.1
# 3  2019-02-08                    169.1
# 4  2019-02-01                    168.9
# 5  2019-01-25                    168.6
# 6  2019-01-18                    168.4
# 7  2019-01-11                    168.0
# 8  2019-01-04                    167.0
# 9  2018-12-14                    166.6
# 10 2018-12-07                    165.5
# 11 2018-11-30                    163.8
# 12 2018-11-23                    162.1
# 13 2018-11-09                    159.1

# %%
vaccines_11to17 = pd.DataFrame()

for k in range(1,7):
    try:
        addayear = pd.read_csv("ExtractCSV/vaccines/vaccines201" + str(k) + ".csv")
        vaccines_11to17 = pd.concat([vaccines_11to17, addayear], ignore_index=True)

    except Exception as e:
        print(f'An error occurred: {e} in {k}')

vaccines_11to17
# Out:
#            Week Total Doses Distributed
# 0      02/03/12   ≈ 132.1 million doses
# 1      01/20/12   ≈ 132.0 million doses
# 2      12/30/11   ≈ 131.2 million doses
# 3      12/16/11   ≈ 130.6 million doses
# 4       12/9/11   ≈ 130.1 million doses
# ..          ...                     ...
# 119  10/07/2016   ≈ 116.3 million doses
# 120  09/23/2016   ≈ 108.8 million doses
# 121  09/16/2016    ≈ 93.2 million doses
# 122  09/09/2016    ≈ 69.7 million doses
# 123  09/02/2016    ≈ 52.7 million doses
#
# [124 rows x 2 columns]

# %%
#Transforming DF to usable data
#Number of doses given
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].astype("str")

vaccines_11to17.dtypes

# %%
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace(" million doses","")
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace("≈ ","")
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].astype("float")


#Number changing from string to date
vaccines_11to17["Week"] = pd.to_datetime(vaccines_11to17["Week"])
vaccines_11to17
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Bootcamp_DA\Challenges\Project3-Data_FullStack\ETL\transform.ipynb Cell 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace(" million doses","")
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace("≈ ","")
# ----> <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].astype("float")
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> #Number changing from string to date
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> vaccines_11to17["Week"] = pd.to_datetime(vaccines_11to17["Week"])
#
# File d:\Anaconda\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File d:\Anaconda\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File d:\Anaconda\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File d:\Anaconda\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File d:\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File d:\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File d:\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1181, in astype_nansafe(arr, dtype, copy, skipna)
#    1177     raise ValueError(msg)
#    1179 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181     return arr.astype(dtype, copy=True)
#    1183 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '= approximate'

# %%
vaccines_11to17.dtypes
# Out:
# Week                       object
# Total Doses Distributed    object
# dtype: object

# %%
vaccines_20to21 = pd.DataFrame()

for k in range(0,1):
    try:
        addayear = pd.read_csv("ExtractCSV/vaccines/vaccines202" + str(k) + ".csv")
        vaccines_20to21 = pd.concat([vaccines_20to21, addayear], ignore_index=True)

    except Exception as e:
        print(f'An error occurred: {e} in {k}')

vaccines_20to21.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Bootcamp_DA\Challenges\Project3-Data_FullStack\ETL\transform.ipynb Cell 4 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     except Exception as e:
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>         print(f'An error occurred: {e} in {k}')
# ---> <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> vaccines_20to21.dtype
#
# File d:\Anaconda\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
#Transforming DF to usable data
#Number of doses given
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace(" M","")
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace("≈ ","")
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].astype(float)
#Number changing from string to date
vaccines_20to21["Week"] = pd.to_datetime(vaccines["Week"])

vaccines_20to21
