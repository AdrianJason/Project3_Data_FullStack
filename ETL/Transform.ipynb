# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
import json

# %% [markdown]
# Vaccines Transform

# %%
#Reading in vaccines2018 to Dataframe
vaccines = pd.read_csv("ExtractCSV/vaccines/vaccines2018.csv")
vaccines
# Out:
#           Week Total Doses Distributed
# 0   03/01/2019               ≈ 169.1 M
# 1   02/22/2019               ≈ 169.1 M
# 2   02/15/2019               ≈ 169.1 M
# 3   02/08/2019               ≈ 169.1 M
# 4   02/01/2019               ≈ 168.9 M
# 5   01/25/2019               ≈ 168.6 M
# 6   01/18/2019               ≈ 168.4 M
# 7   01/11/2019               ≈ 168.0 M
# 8   01/04/2019               ≈ 167.0 M
# 9   12/14/2018               ≈ 166.6 M
# 10  12/07/2018               ≈ 165.5 M
# 11  11/30/2018               ≈ 163.8 M
# 12  11/23/2018               ≈ 162.1 M
# 13  11/09/2018               ≈ 159.1 M

# %%
#Transforming DF to usable data
#Number of doses given
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace(" M","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace("≈ ","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].str.replace("≈","")
vaccines["Total Doses Distributed"] = vaccines["Total Doses Distributed"].astype(float)
#Number changing from string to date
vaccines["Week"] = pd.to_datetime(vaccines["Week"])
vaccines
# Out:
#          Week  Total Doses Distributed
# 0  2019-03-01                    169.1
# 1  2019-02-22                    169.1
# 2  2019-02-15                    169.1
# 3  2019-02-08                    169.1
# 4  2019-02-01                    168.9
# 5  2019-01-25                    168.6
# 6  2019-01-18                    168.4
# 7  2019-01-11                    168.0
# 8  2019-01-04                    167.0
# 9  2018-12-14                    166.6
# 10 2018-12-07                    165.5
# 11 2018-11-30                    163.8
# 12 2018-11-23                    162.1
# 13 2018-11-09                    159.1

# %%
vaccines_11to17 = pd.DataFrame()

for k in range(1,7):
    try:
        addayear = pd.read_csv("ExtractCSV/vaccines/vaccines201" + str(k) + ".csv")
        vaccines_11to17 = pd.concat([vaccines_11to17, addayear], ignore_index=True)

    except Exception as e:
        print(f'An error occurred: {e} in {k}')

vaccines_11to17
# Out:
#            Week Total Doses Distributed
# 0      02/03/12   ≈ 132.1 million doses
# 1      01/20/12   ≈ 132.0 million doses
# 2      12/30/11   ≈ 131.2 million doses
# 3      12/16/11   ≈ 130.6 million doses
# 4       12/9/11   ≈ 130.1 million doses
# ..          ...                     ...
# 119  10/07/2016   ≈ 116.3 million doses
# 120  09/23/2016   ≈ 108.8 million doses
# 121  09/16/2016    ≈ 93.2 million doses
# 122  09/09/2016    ≈ 69.7 million doses
# 123  09/02/2016    ≈ 52.7 million doses
#
# [124 rows x 2 columns]

# %%
approximate = "≈ = approximate"
vaccines_11to17.drop(vaccines_11to17.loc[(vaccines_11to17["Week"]== approximate),:].index,inplace=True)
vaccines_11to17
# Out:
#            Week Total Doses Distributed
# 0      02/03/12   ≈ 132.1 million doses
# 1      01/20/12   ≈ 132.0 million doses
# 2      12/30/11   ≈ 131.2 million doses
# 3      12/16/11   ≈ 130.6 million doses
# 4       12/9/11   ≈ 130.1 million doses
# ..          ...                     ...
# 119  10/07/2016   ≈ 116.3 million doses
# 120  09/23/2016   ≈ 108.8 million doses
# 121  09/16/2016    ≈ 93.2 million doses
# 122  09/09/2016    ≈ 69.7 million doses
# 123  09/02/2016    ≈ 52.7 million doses
#
# [121 rows x 2 columns]

# %%
#Transforming DF to usable data
#Number of doses given
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace(" million doses","")
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].str.replace("≈ ","")
vaccines_11to17["Total Doses Distributed"] = vaccines_11to17["Total Doses Distributed"].astype(float)
#Number changing from string to date
vaccines_11to17["Week"] = pd.to_datetime(vaccines_11to17["Week"])
vaccines_11to17
# Out:
#           Week  Total Doses Distributed
# 0   2012-02-03                    132.1
# 1   2012-01-20                    132.0
# 2   2011-12-30                    131.2
# 3   2011-12-16                    130.6
# 4   2011-12-09                    130.1
# ..         ...                      ...
# 119 2016-10-07                    116.3
# 120 2016-09-23                    108.8
# 121 2016-09-16                     93.2
# 122 2016-09-09                     69.7
# 123 2016-09-02                     52.7
#
# [121 rows x 2 columns]

# %%
vaccines_20to21 = pd.DataFrame()

for k in range(0,1):
    try:
        addayear = pd.read_csv("ExtractCSV/vaccines/vaccines202" + str(k) + ".csv")
        vaccines_20to21 = pd.concat([vaccines_20to21, addayear], ignore_index=True)

    except Exception as e:
        print(f'An error occurred: {e} in {k}')

vaccines_20to21
# Out:
#           Week Total Doses Distributed
# 0   2/26/​2021                 193.8 M
# 1   2/12/​2021                 193.7 M
# 2    2/5/​2021                 193.6 M
# 3   1/29/​2021                 193.4 M
# 4   1/15/​2021                 193.2 M
# 5     1/8/2021                 192.9 M
# 6     1/1/2021                 192.5 M
# 7   12/25/2020                 192.3 M
# 8   12/18/2020                 192.1 M
# 9   12/11/2020                 190.4 M
# 10   12/4/2020                 189.4 M
# 11  11/27/2020                 188.0 M
# 12  11/20/2020                186.9 M*
# 13  11/13/2020                 183.0 M
# 14   11/6/2020                 179.6 M
# 15  10/30/2020                 172.3 M
# 16  10/23/2020                 164.7 M
# 17  10/16/2020                 154.6 M
# 18   10/9/2020                 139.4 M
# 19   10/2/2020                 124.2 M
# 20   9/25/2020                 105.5 M
# 21   9/18/2020                  87.5 M
# 22   9/11/2020                  66.6 M
# 23    9/4/2020                  47.6 M
# 24   8/28/2020                  32.4 M
# 25   8/21/2020                  21.8 M
# 26   8/14/2020                  13.7 M

# %%
vaccines_20to21.dtypes
# Out:
# Week                       object
# Total Doses Distributed    object
# dtype: object

# %%
#Transforming DF to usable data
#Number of doses given
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace(" M","")
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace("≈ ","")
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace("*","")
vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].astype(float)
#Number changing from string to date
vaccines_20to21["Week"] = pd.to_datetime(vaccines_20to21["Week"])

vaccines_20to21
# Out:
# C:\Users\a_don\AppData\Local\Temp\ipykernel_9716\3886167741.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].str.replace("*","")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# d:\Bootcamp_DA\Challenges\Project3-Data_FullStack\ETL\transform.ipynb Cell 10 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> vaccines_20to21["Total Doses Distributed"] = vaccines_20to21["Total Doses Distributed"].astype(float)
#       <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> #Number changing from string to date
# ----> <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> vaccines_20to21["Week"] = pd.to_datetime(vaccines_20to21["Week"])
#      <a href='vscode-notebook-cell:/d%3A/Bootcamp_DA/Challenges/Project3-Data_FullStack/ETL/transform.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> vaccines_20to21
#
# File d:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File d:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File d:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File d:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File d:\Anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File d:\Anaconda\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File d:\Anaconda\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 2/26/​2021

# %% [markdown]
# Flu Case Transform

# %%
flu_10to16 = pd.DataFrame()

for k in range(2,6):
    try:
        addayear = pd.read_csv("ExtractCSV/flucases/flu201" + str(k) + ".csv")
    
        flu_10to16 = pd.concat([flu_10to16, addayear], ignore_index=True)

    except Exception as e:
        print(f'An error occurred: {e} in {k}')

flu_10to16
# Out:
#    Unnamed: 0_level_0 Symptomatic Illnesses   Symptomatic Illnesses.1  \
# 0           Age group              Estimate                  95% Cr I
# 1             0-4 yrs               3563980    (3,057,118, 4,268,167)
# 2            5-17 yrs               6672657    (5,711,369, 7,969,110)
# 3           18-49 yrs              11391195   (9,683,756, 14,278,920)
# 4           50-64 yrs               7861032    (6,737,366, 9,662,138)
# 5             65+ yrs               4190308    (3,634,176, 5,203,875)
# 6            All ages              33679171  (31,711,102, 37,994,457)
# 7           Age group              Estimate                  95% Cr I
# 8             0-4 yrs               2525568    (2,193,604, 2,950,196)
# 9            5-17 yrs               3983742    (3,433,463, 4,695,861)
# 10          18-49 yrs              13038323  (11,459,968, 15,201,283)
# 11          50-64 yrs               8484977    (7,462,475, 9,864,079)
# 12            65+ yrs               1707384    (1,494,059, 2,039,988)
# 13           All ages              29739994  (27,857,029, 32,700,078)
# 14          Age group              Estimate                  95% Cr I
# 15            0-4 yrs               3207314    (2,755,504, 3,808,657)
# 16           5-17 yrs               6388401    (5,487,505, 7,554,676)
# 17          18-49 yrs               8606083    (7,750,712, 9,693,873)
# 18          50-64 yrs               7283766    (6,374,888, 8,485,648)
# 19            65+ yrs               4679888    (4,072,076, 5,570,118)
# 20           All ages              30165452  (28,571,644, 32,660,556)
# 21          Age group              Estimate                  95% Cr I
# 22            0-4 yrs               2195276    (1,517,785, 4,264,279)
# 23           5-17 yrs               4140269    (2,866,365, 6,881,275)
# 24          18-49 yrs               9121242   (6,524,729, 14,616,919)
# 25          50-64 yrs               6640358   (4,539,659, 11,816,145)
# 26            65+ yrs               1407174      (807,910, 3,568,190)
# 27           All ages              23504319  (19,928,951, 32,524,195)
#
#    Medical Visits          Medical Visits.1 Hospitalizations  \
# 0        Estimate                  95% Cr I         Estimate
# 1         2387867    (1,994,497, 2,915,341)            24846
# 2         3469781    (2,873,386, 4,239,106)            18296
# 3         4214742    (3,406,874, 5,548,686)            63939
# 4         3380244    (2,746,841, 4,328,341)            83364
# 5         2346572    (1,954,820, 3,017,303)           380937
# 6        15799206  (14,698,757, 17,986,517)           571382
# 7        Estimate                  95% Cr I         Estimate
# 8         1692131    (1,426,310, 2,024,015)            17607
# 9         2071546    (1,725,701, 2,506,930)            10923
# 10        4824179    (3,999,013, 5,949,705)            73184
# 11        3648540    (3,013,667, 4,473,016)            89981
# 12         956135      (795,414, 1,191,320)           155217
# 13       13192531  (12,102,484, 14,799,134)           346912
# 14       Estimate                  95% Cr I         Estimate
# 15        2148900    (1,794,219, 2,614,247)            22360
# 16        3321969    (2,766,223, 4,055,360)            17516
# 17        3184251    (2,649,182, 3,815,288)            48306
# 18        3132019    (2,568,790, 3,877,954)            77242
# 19        2620737    (2,159,437, 3,246,219)           425444
# 20       14407876  (13,330,862, 15,907,256)           590869
# 21       Estimate                  95% Cr I         Estimate
# 22        1470835    (1,000,088, 2,852,211)            15304
# 23        2152940    (1,473,591, 3,637,791)            11352
# 24        3374860    (2,338,468, 5,480,793)            51198
# 25        2855354    (1,903,319, 5,151,090)            70419
# 26         788018      (446,501, 2,016,037)           127925
# 27       10642006   (8,932,013, 14,736,247)           276198
#
#     Hospitalizations.1    Deaths          Deaths.1
# 0             95% Cr I  Estimate          95% Cr I
# 1     (21,313, 29,756)       291         (69, 705)
# 2     (15,660, 21,851)       870      (381, 2,119)
# 3     (54,355, 80,148)      2072    (1,072, 5,040)
# 4    (71,448, 102,464)      4170    (2,774, 7,198)
# 5   (330,380, 473,080)     35167  (27,928, 49,636)
# 6   (524,174, 673,678)     42570  (35,785, 58,386)
# 7             95% Cr I  Estimate          95% Cr I
# 8     (15,293, 20,567)        74          (0, 216)
# 9      (9,414, 12,876)        56          (0, 240)
# 10    (64,325, 85,325)      3422    (2,419, 5,330)
# 11   (79,137, 104,606)      5964    (4,405, 8,935)
# 12  (135,824, 185,453)     28414  (23,222, 39,030)
# 13  (324,890, 385,289)     37930  (33,023, 49,640)
# 14            95% Cr I  Estimate          95% Cr I
# 15    (19,210, 26,552)       396        (171, 752)
# 16    (15,046, 20,714)       407        (149, 799)
# 17    (43,505, 54,412)       985      (552, 1,705)
# 18    (67,604, 89,988)      4780    (3,444, 7,014)
# 19  (370,189, 506,374)     44808  (37,403, 57,181)
# 20  (535,829, 675,052)     51376  (44,163, 64,254)
# 21            95% Cr I  Estimate          95% Cr I
# 22    (10,581, 29,729)       180          (0, 436)
# 23     (7,859, 18,868)        88          (0, 241)
# 24    (36,623, 82,045)      1703    (1,099, 2,523)
# 25   (48,142, 125,307)      3277    (2,352, 4,659)
# 26   (73,446, 324,381)     17458  (12,204, 29,356)
# 27  (214,721, 482,650)     22705  (17,373, 34,671)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
